# %%
from tkinter.font import names

import pandas as pd
import numpy as np
from debugpy.common.timestamp import current

# %%
df = pd.read_csv("../data/raw_data/meta1.csv")

# %%
df
# Out:
#                       WSI     GH_ID         BEGIN_DATE           END_DATE  \
# 0         0-20000-0-11406  L3CHEB01  1863-10-01T00:00Z  1919-12-31T23:59Z
# 1         0-20000-0-11406  L3CHEB01  1933-05-07T00:00Z  1938-04-30T23:59Z
# 2         0-20000-0-11406  L3CHEB01  1943-06-01T00:00Z  1945-01-31T23:59Z
# 3         0-20000-0-11406  L3CHEB01  1951-01-01T00:00Z  1960-12-31T23:59Z
# 4         0-20000-0-11406  L3CHEB01  1961-01-01T00:00Z  2000-12-31T23:59Z
# ...                   ...       ...                ...                ...
# 5485  0-203-0-42109005002  B1STHR01  1980-01-01T00:00Z  3999-12-31T23:59Z
# 5486  0-203-0-42109007001  B1PITI01  1944-10-01T00:00Z  1961-12-31T23:59Z
# 5487  0-203-0-42109026001  B1LOPE01  1902-01-01T00:00Z  1902-12-31T23:59Z
# 5488  0-203-0-42109026001  B1LOPE01  1936-03-15T00:00Z  1946-06-30T23:59Z
# 5489  0-203-0-42109026001  B1LOPE01  1988-08-01T00:00Z  1990-04-30T23:59Z
#
#             FULL_NAME     GEOGR1     GEOGR2  ELEVATION  Unnamed: 8
# ...

# %%
names = df["FULL_NAME"].str.contains("Praha",regex=True)

# %%
names = df["FULL_NAME"].str.contains("Praha",regex=True)
df = df[names]
df = df["END_DATE"] > pd.Timestamp.now(tz="utc")
# Out:
# ---------------------------------------------------------------------------
# ArrowNotImplementedError                  Traceback (most recent call last)
# File ~\PycharmProjects\Weather_Processing\.venv\Lib\site-packages\pandas\core\arrays\arrow\array.py:944, in ArrowExtensionArray._cmp_method(self, other, op)
#     943 try:
# --> 944     result = pc_func(self._pa_array, self._box_pa(other))
#     945 except (pa.lib.ArrowNotImplementedError, pa.lib.ArrowInvalid):
#
# File ~\PycharmProjects\Weather_Processing\.venv\Lib\site-packages\pyarrow\compute.py:254, in _make_generic_wrapper.<locals>.wrapper(memory_pool, *args)
#     253     return Expression._call(func_name, list(args))
# --> 254 return func.call(args, None, memory_pool)
#
# File pyarrow/_compute.pyx:399, in pyarrow._compute.Function.call()
# --> 399 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
# ...

# %%
df["END_DATE"] = pd.to_datetime(df["END_DATE"],errors="coerce",format="mixed",dayfirst=True)

df = df[names]

print(names.sum())
df = df["END_DATE"] > pd.Timestamp.now(tz="utc")
df
# Out:
# 41
# 58      False
# 59      False
# 60      False
# 61       True
# 62      False
# 63      False
# 64       True
# 65      False
# 66      False
# 67       True
# 72      False
# 73      False
# 74       True
# 434     False
# 1077    False
# 1078    False
# 1079     True
# 1389     True
# 1390    False
# 1394    False
# 1395    False
# 1396    False
# 1397     True
# 1398    False
# 1399     True
# 1400    False
# 1401    False
# 1402    False
# 1403     True
# 1404    False
# 1408    False
# 1409     True
# 2032    False
# 2180    False
# 2181    False
# 2182    False
# 2183     True
# 2184    False
# 2185    False
# 2186     True
# 2332    False
# Name: END_DATE, dtype: bool

# %%
print(len(df[date]))
# Out:
# 12

# %%
df = df[date]

# %%
list_of_WSI = df["WSI"].to_list()
list_of_WSI
# Out:
# ['0-20000-0-11518',
#  '0-20000-0-11519',
#  '0-20000-0-11520',
#  '0-20000-0-11567',
#  '0-203-0-10904013001',
#  '0-203-0-11105048001',
#  '0-203-0-11201020001',
#  '0-203-0-11201020003',
#  '0-203-0-11201024001',
#  '0-203-0-11202007001',
#  '0-203-0-11514',
#  '0-203-0-11515']

# %%
df
# Out:
#                       WSI     GH_ID         BEGIN_DATE  \
# 61        0-20000-0-11518  P1PRUZ01  2000-01-01T00:00Z
# 64        0-20000-0-11519  P1PKAR01  2024-09-01T00:00Z
# 67        0-20000-0-11520  P1PLIB01  2018-05-17T00:00Z
# 74        0-20000-0-11567  P1PKBE01  2010-10-01T00:00Z
# 1079  0-203-0-10904013001  P1PKOM01  2017-12-07T12:00Z
# 1389  0-203-0-11105048001  P1PZKO01  1961-01-01T00:00Z
# 1397  0-203-0-11201020001  P1PVIN01  2019-01-01T00:00Z
# 1399  0-203-0-11201020003  P1PCHO01  1997-01-01T00:00Z
# 1403  0-203-0-11201024001  P1PBRE01  2013-09-01T00:00Z
# 1409  0-203-0-11202007001  P1PSUC01  1961-01-01T00:00Z
# 2183        0-203-0-11514  P1PKLE01  2023-01-01T00:00Z
# 2186        0-203-0-11515  P1PKLM01  2023-01-01T00:00Z
#
#                       END_DATE                 FULL_NAME     GEOGR1  \
# 61   3999-12-31 23:59:00+00:00             Praha  Ruzyně  14.255556
# 64   3999-12-31 23:59:00+00:00             Praha  Karlov  14.427778
# ...
